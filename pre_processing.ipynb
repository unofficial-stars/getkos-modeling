# %%
import pandas as pd
import json

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %% [markdown]
# <img src="img_notes/histo_harga_data_choosen.png">

# %%
df = pd.read_csv('merged_data - data_choosen.csv')

count_area = df.groupby(['area']).size().reset_index(name='counts')
observed_area = list(count_area[count_area['counts']>=4]['area'].values)

df_observed = df[df['area'].isin(observed_area)].reset_index(drop=True)

# %%
df_observed['kost_name_rough'] = df_observed['texts'].apply(lambda x: ' '.join(x.split()))
df_observed['fasilitas_ls'] = df_observed['fasilitas']\
.apply(lambda x: str(x).replace("'","").replace("[","").replace("]","").split(","))

# %%
# lowercase and strip
def lowstrip(x):
	ls = []
	for val in x:
		ls.append(val.lower().strip())
	return ls

# %%
df_observed['fasilitas_lsclean'] = df_observed['fasilitas_ls'].apply(lambda x: lowstrip(x))
df_observed['fasilitas_lsclean_str'] = df_observed['fasilitas_lsclean'].apply(lambda x: str(x))

# %%
df_observed = df_observed[['kost_name_rough', 'kota', 'type_kos', 'area', \
                           'fasilitas_lsclean_str', 'fasilitas_lsclean', 'harga_nomina']]

# %%
df_observed['fasilitas_lsclean'][:4]
# Out:
# 0    [k. mandi dalam, wifi, akses 24 jam]
# 1    [k. mandi dalam, wifi, akses 24 jam]
# 2    [k. mandi dalam, wifi, akses 24 jam]
# 3    [k. mandi dalam, wifi, akses 24 jam]
# Name: fasilitas_lsclean, dtype: object

# %%
df_observed['fasilitas_lsclean_str'].unique()
# Out:
# array(["['k. mandi dalam', 'wifi', 'akses 24 jam']",
#        "['wifi', 'akses 24 jam']", "['']", "['k. mandi dalam', 'wifi']",
#        "['akses 24 jam']", "['k. mandi dalam', 'akses 24 jam']",
#        "['k. mandi dalam']", "['wifi']"], dtype=object)

# %%
for i in [i for i in df_observed.columns][2:4]:
    df_observed[i] = df_observed[i].apply(lambda x: x.lower())

# %%
df_observed
# Out:
#                                         kost_name_rough      kota type_kos  \
# 0     Campur Sisa 2 Kamar Kost De' Leota Tipe C Pete...  semarang   campur
# 1     Kos Andalan Campur Kost DS CoLive 34 Pecinan S...  semarang   campur
# 2     Kos Andalan Campur Kost Altaf Putra Tipe A Pur...  semarang   campur
# 3     Kos Andalan Campur Kost Pantes Brumbungan Loyo...  semarang   campur
# 4     Campur Sisa 3 Kamar Kost De' Leota Tipe A Pete...  semarang   campur
# ...                                                 ...       ...      ...
# 1063  Putri Kost Sonnya Klojen Malang Klojen WiFi Rp...    malang    putri
# 1064  Putri Kost Srikandi Sukun Malang Sukun WiFi · ...    malang    putri
# 1065  Putri Kost The Imajo Depok Sleman Depok K. Man...     jogja    putri
# 1066  Putri Kost WatuGong Tipe A Lowokwaru Malang Lo...    malang    putri
# 1067  Putri Kost Wisma Aisyah Bantul Bantul K. Mandi...     jogja    putri
#
#                  area                       fasilitas_lsclean_str  \
# 0     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 2      semarang timur  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 3     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 4     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# ...               ...                                         ...
# 1063           klojen                                    ['wifi']
# 1064            sukun                    ['wifi', 'akses 24 jam']
# 1065            depok  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1066        lowokwaru  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1067           bantul                  ['k. mandi dalam', 'wifi']
#
#                          fasilitas_lsclean  harga_nomina
# 0     [k. mandi dalam, wifi, akses 24 jam]       1600000
# 1     [k. mandi dalam, wifi, akses 24 jam]       2000000
# 2     [k. mandi dalam, wifi, akses 24 jam]       1000000
# 3     [k. mandi dalam, wifi, akses 24 jam]       3500000
# 4     [k. mandi dalam, wifi, akses 24 jam]       1400000
# ...                                    ...           ...
# 1063                                [wifi]        700000
# 1064                  [wifi, akses 24 jam]        300000
# 1065  [k. mandi dalam, wifi, akses 24 jam]       1299999
# 1066  [k. mandi dalam, wifi, akses 24 jam]       1200000
# 1067                [k. mandi dalam, wifi]        550000
#
# [1068 rows x 7 columns]

# %%
for i in [i for i in df_observed.columns][1:4]:
    print(df_observed[i].unique())
# Out:
# ['semarang' 'jakarta' 'bandung' 'surabaya' 'malang' 'jogja']
# ['campur' 'putri' 'putra']
# ['semarang tengah' 'semarang timur' 'semarang utara' 'pedurungan'
#  'tembalang' 'genuk' 'semarang selatan' 'banyumanik' 'gajahmungkur'
#  'semarang barat' 'ngaliyan' 'tanah abang' 'setiabudi' 'tebet'
#  'duren sawit' 'sawah besar' 'gambir' 'palmerah' 'tanjung priok' 'koja'
#  'senen' 'cilandak' 'kelapa gading' 'grogol petamburan' 'serpong'
#  'coblong' 'cibeunying kaler' 'sukajadi' 'cidadap' 'cicendo'
#  'bandung wetan' 'regol' 'lengkong' 'bandung kidul' 'batununggal'
#  'jatinangor' 'buahbatu' 'arcamanik' 'babakan ciparay' 'bojongloa kidul'
#  'wonocolo' 'gubeng' 'rungkut' 'tegalsari' 'gayungan' 'wonokromo' 'wiyung'
#  'karang pilang' 'dukuhpakis' 'tambaksari' 'sukolilo' 'mulyorejo'
#  'gunung anyar' 'singosari' 'godean' 'kepanjen' 'bantul' 'sukun'
#  'umbulharjo' 'batu' 'klojen' 'mergangsan' 'sedati' 'lowokwaru' 'ngemplak'
#  'waru' 'blimbing' 'ngaglik' 'gedong tengen' 'depok' 'gondomanan' 'mlati'
#  'gondokusuman' 'jetis' 'mantrijeron' 'tegalrejo' 'pakualaman']

# %%
dict_score = {'k. mandi dalam':2, 'wifi':2, 'akses 24 jam':2}

def check_kmd(x):
    if 'k. mandi dalam' in x:
        return dict_score['k. mandi dalam']
    else:
        return 0

def check_wifi(x):
    if 'wifi' in x:
        return dict_score['wifi']
    else:
        return 0

def check_akdjam(x):
    if 'akses 24 jam' in x:
        return dict_score['akses 24 jam']
    else:
        return 0

# %%
df_observed['fasilitas_lsclean'][0]
# Out:
# ['k. mandi dalam', 'wifi', 'akses 24 jam']

# %%
df_observed['k_mndi_dlm'] = df_observed['fasilitas_lsclean'].apply(lambda x: check_kmd(x))
df_observed['wifi'] = df_observed['fasilitas_lsclean'].apply(lambda x: check_wifi(x))
df_observed['aks_dmpat_jam'] = df_observed['fasilitas_lsclean'].apply(lambda x: check_akdjam(x))

# %%
df_observed
# Out:
#                                         kost_name_rough      kota type_kos  \
# 0     Campur Sisa 2 Kamar Kost De' Leota Tipe C Pete...  semarang   campur
# 1     Kos Andalan Campur Kost DS CoLive 34 Pecinan S...  semarang   campur
# 2     Kos Andalan Campur Kost Altaf Putra Tipe A Pur...  semarang   campur
# 3     Kos Andalan Campur Kost Pantes Brumbungan Loyo...  semarang   campur
# 4     Campur Sisa 3 Kamar Kost De' Leota Tipe A Pete...  semarang   campur
# ...                                                 ...       ...      ...
# 1063  Putri Kost Sonnya Klojen Malang Klojen WiFi Rp...    malang    putri
# 1064  Putri Kost Srikandi Sukun Malang Sukun WiFi · ...    malang    putri
# 1065  Putri Kost The Imajo Depok Sleman Depok K. Man...     jogja    putri
# 1066  Putri Kost WatuGong Tipe A Lowokwaru Malang Lo...    malang    putri
# 1067  Putri Kost Wisma Aisyah Bantul Bantul K. Mandi...     jogja    putri
#
#                  area                       fasilitas_lsclean_str  \
# 0     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 2      semarang timur  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 3     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 4     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# ...               ...                                         ...
# 1063           klojen                                    ['wifi']
# 1064            sukun                    ['wifi', 'akses 24 jam']
# 1065            depok  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1066        lowokwaru  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1067           bantul                  ['k. mandi dalam', 'wifi']
#
#                          fasilitas_lsclean  harga_nomina  k_mndi_dlm  wifi  \
# 0     [k. mandi dalam, wifi, akses 24 jam]       1600000           2     2
# 1     [k. mandi dalam, wifi, akses 24 jam]       2000000           2     2
# 2     [k. mandi dalam, wifi, akses 24 jam]       1000000           2     2
# 3     [k. mandi dalam, wifi, akses 24 jam]       3500000           2     2
# 4     [k. mandi dalam, wifi, akses 24 jam]       1400000           2     2
# ...                                    ...           ...         ...   ...
# 1063                                [wifi]        700000           0     2
# 1064                  [wifi, akses 24 jam]        300000           0     2
# 1065  [k. mandi dalam, wifi, akses 24 jam]       1299999           2     2
# 1066  [k. mandi dalam, wifi, akses 24 jam]       1200000           2     2
# 1067                [k. mandi dalam, wifi]        550000           2     2
#
#       aks_dmpat_jam
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# ...             ...
# 1063              0
# 1064              2
# 1065              2
# 1066              2
# 1067              0
#
# [1068 rows x 10 columns]

# %%
df_observed['facility_score'] = df_observed['k_mndi_dlm'] + df_observed['wifi'] + df_observed['aks_dmpat_jam']

# %%
df_observed
# Out:
#                                         kost_name_rough      kota type_kos  \
# 0     Campur Sisa 2 Kamar Kost De' Leota Tipe C Pete...  semarang   campur
# 1     Kos Andalan Campur Kost DS CoLive 34 Pecinan S...  semarang   campur
# 2     Kos Andalan Campur Kost Altaf Putra Tipe A Pur...  semarang   campur
# 3     Kos Andalan Campur Kost Pantes Brumbungan Loyo...  semarang   campur
# 4     Campur Sisa 3 Kamar Kost De' Leota Tipe A Pete...  semarang   campur
# ...                                                 ...       ...      ...
# 1063  Putri Kost Sonnya Klojen Malang Klojen WiFi Rp...    malang    putri
# 1064  Putri Kost Srikandi Sukun Malang Sukun WiFi · ...    malang    putri
# 1065  Putri Kost The Imajo Depok Sleman Depok K. Man...     jogja    putri
# 1066  Putri Kost WatuGong Tipe A Lowokwaru Malang Lo...    malang    putri
# 1067  Putri Kost Wisma Aisyah Bantul Bantul K. Mandi...     jogja    putri
#
#                  area                       fasilitas_lsclean_str  \
# 0     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 2      semarang timur  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 3     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 4     semarang tengah  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# ...               ...                                         ...
# 1063           klojen                                    ['wifi']
# 1064            sukun                    ['wifi', 'akses 24 jam']
# 1065            depok  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1066        lowokwaru  ['k. mandi dalam', 'wifi', 'akses 24 jam']
# 1067           bantul                  ['k. mandi dalam', 'wifi']
#
#                          fasilitas_lsclean  harga_nomina  k_mndi_dlm  wifi  \
# 0     [k. mandi dalam, wifi, akses 24 jam]       1600000           2     2
# 1     [k. mandi dalam, wifi, akses 24 jam]       2000000           2     2
# 2     [k. mandi dalam, wifi, akses 24 jam]       1000000           2     2
# 3     [k. mandi dalam, wifi, akses 24 jam]       3500000           2     2
# 4     [k. mandi dalam, wifi, akses 24 jam]       1400000           2     2
# ...                                    ...           ...         ...   ...
# 1063                                [wifi]        700000           0     2
# 1064                  [wifi, akses 24 jam]        300000           0     2
# 1065  [k. mandi dalam, wifi, akses 24 jam]       1299999           2     2
# 1066  [k. mandi dalam, wifi, akses 24 jam]       1200000           2     2
# 1067                [k. mandi dalam, wifi]        550000           2     2
#
#       aks_dmpat_jam  facility_score
# 0                 2               6
# 1                 2               6
# 2                 2               6
# 3                 2               6
# 4                 2               6
# ...             ...             ...
# 1063              0               2
# 1064              2               4
# 1065              2               6
# 1066              2               6
# 1067              0               4
#
# [1068 rows x 11 columns]

# %%
df_features = df_observed[['kost_name_rough','kota','type_kos',
                           'area','facility_score','harga_nomina']]

# %%
df_features
# Out:
#                                         kost_name_rough      kota type_kos  \
# 0     Campur Sisa 2 Kamar Kost De' Leota Tipe C Pete...  semarang   campur
# 1     Kos Andalan Campur Kost DS CoLive 34 Pecinan S...  semarang   campur
# 2     Kos Andalan Campur Kost Altaf Putra Tipe A Pur...  semarang   campur
# 3     Kos Andalan Campur Kost Pantes Brumbungan Loyo...  semarang   campur
# 4     Campur Sisa 3 Kamar Kost De' Leota Tipe A Pete...  semarang   campur
# ...                                                 ...       ...      ...
# 1063  Putri Kost Sonnya Klojen Malang Klojen WiFi Rp...    malang    putri
# 1064  Putri Kost Srikandi Sukun Malang Sukun WiFi · ...    malang    putri
# 1065  Putri Kost The Imajo Depok Sleman Depok K. Man...     jogja    putri
# 1066  Putri Kost WatuGong Tipe A Lowokwaru Malang Lo...    malang    putri
# 1067  Putri Kost Wisma Aisyah Bantul Bantul K. Mandi...     jogja    putri
#
#                  area  facility_score  harga_nomina
# 0     semarang tengah               6       1600000
# 1     semarang tengah               6       2000000
# 2      semarang timur               6       1000000
# 3     semarang tengah               6       3500000
# 4     semarang tengah               6       1400000
# ...               ...             ...           ...
# 1063           klojen               2        700000
# 1064            sukun               4        300000
# 1065            depok               6       1299999
# 1066        lowokwaru               6       1200000
# 1067           bantul               4        550000
#
# [1068 rows x 6 columns]

# %%
df_features.to_csv('features.csv',index=False)
